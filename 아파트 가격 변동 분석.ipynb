# %%
import pandas as pd
import numpy as np

# 시각화
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\ProgramData\Anaconda3\envs\song\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df_first = pd.read_csv('C:/jupyter_project//아파트1.csv',encoding='cp949',dtype={'CODE':np.str})

# %%
df_sec = pd.read_csv('C:/jupyter_project/아파트 가격 변동 분석/아파트2.csv',encoding='cp949',dtype={'CODE':np.str})

# %%
df_final = pd.read_csv('C:/jupyter_project/아파트 가격 변동 분석/아파트3.csv',encoding='cp949',dtype={'CODE':np.str})

# %%
df_first.shape
# Out:
# (983690, 12)

# %%
df_sec.shape
# Out:
# (1022082, 12)

# %%
df_final.shape
# Out:
# (973089, 12)

# %%
df_first.head()
# Out:
#            시군구   번지   본번  부번           단지명  전용면적(㎡)    계약년월  계약일 거래금액(만원)   층  \
# 0  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   13    6,300  15
# 1  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   21    7,700  15
# 2  강원도 강릉시 견소동  202  202   0          송정한신   84.945  201504   27   14,000  10
# 3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    1   14,500  13
# 4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    8   14,000   7
#
#    건축년도           도로명
# 0  1997   경강로2539번길 8
# 1  1997   경강로2539번길 8
# 2  1997   경강로2539번길 8
# 3  2005  경강로2539번길 22
# 4  2005  경강로2539번길 22

# %%
df_sec.head()
# Out:
#            시군구   번지   본번  부번           단지명  전용면적(㎡)    계약년월  계약일 거래금액(만원)  층  \
# 0  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트    84.99  201610    4   24,000  7
# 1  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트    59.99  201610    4   15,250  4
# 2  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트    59.99  201610    5   12,000  2
# 3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트    59.99  201610   14   15,900  9
# 4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트    84.99  201610   16   19,950  4
#
#    건축년도           도로명
# 0  2005  경강로2539번길 22
# 1  2005  경강로2539번길 22
# 2  2005  경강로2539번길 22
# 3  2005  경강로2539번길 22
# 4  2005  경강로2539번길 22

# %%
df_final.head()
# Out:
#            시군구    번지    본번  부번           단지명   전용면적(㎡)    계약년월  계약일 거래금액(만원)  \
# 0  강원도 강릉시 견소동   289   289   0  송정해변신도브래뉴아파트   59.9900  201808    9   18,600
# 1  강원도 강릉시 견소동   289   289   0  송정해변신도브래뉴아파트   59.9900  201808   10   19,000
# 2  강원도 강릉시 견소동   289   289   0  송정해변신도브래뉴아파트   84.9900  201808   31   26,600
# 3   강원도 강릉시 교동  1982  1982   0   강릉교동롯데캐슬1단지  163.9852  201808   27   38,500
# 4   강원도 강릉시 교동  1982  1982   0   강릉교동롯데캐슬1단지  135.1727  201808   30   36,300
#
#     층  건축년도           도로명
# 0  12  2005  경강로2539번길 23
# 1  14  2005  경강로2539번길 22
# 2  14  2005  경강로2539번길 22
# 3   2  2009   화부산로99번길 12
# 4  12  2009   화부산로99번길 12

# %%
# df_first_prepare 와 df_last_prepare 합쳐주기

df=pd.concat([df_first,df_sec,df_final])
df
# Out:
#                  시군구     번지   본번  부번           단지명  전용면적(㎡)    계약년월  계약일  \
# 0        강원도 강릉시 견소동    202  202   0          송정한신  39.0800  201504   13
# 1        강원도 강릉시 견소동    202  202   0          송정한신  39.0800  201504   21
# 2        강원도 강릉시 견소동    202  202   0          송정한신  84.9450  201504   27
# 3        강원도 강릉시 견소동    289  289   0  송정해변신도브래뉴아파트  59.9900  201504    1
# 4        강원도 강릉시 견소동    289  289   0  송정해변신도브래뉴아파트  59.9900  201504    8
# ...              ...    ...  ...  ..           ...      ...     ...  ...
# 973084  충청북도 충주시 호암동  547-6  547   6          호반현대  59.7600  202004    7
# 973085  충청북도 충주시 호암동  547-6  547   6          호반현대  84.9600  202004   10
# 973086  충청북도 충주시 호암동  547-6  547   6          호반현대  84.9600  202004   16
# 973087  충청북도 충주시 호암동  547-6  547   6          호반현대  59.7600  202004   28
# 973088  충청북도 충주시 호암동    905  905   0         호암동수채  84.9254  202004   21
#
#        거래금액(만원)   층  건축년도           도로명
# 0         6,300  15  1997   경강로2539번길 8
# ...

# %%
df.to_csv('C:/jupyter_project/아파트 가격 변동 분석/main data.csv',encoding='cp949')

# %%
df= pd.read_csv('C:/jupyter_project/아파트 가격 변동 분석/main data.csv',encoding='cp949',dtype={'CODE':np.str})

# %%
df.head()
# Out:
#    Unnamed: 0          시군구   번지   본번  부번           단지명  전용면적(㎡)    계약년월  계약일  \
# 0           0  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   13
# 1           1  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   21
# 2           2  강원도 강릉시 견소동  202  202   0          송정한신   84.945  201504   27
# 3           3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    1
# 4           4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    8
#
#   거래금액(만원)   층  건축년도           도로명
# 0    6,300  15  1997   경강로2539번길 8
# 1    7,700  15  1997   경강로2539번길 8
# 2   14,000  10  1997   경강로2539번길 8
# 3   14,500  13  2005  경강로2539번길 22
# 4   14,000   7  2005  경강로2539번길 22

# %%
df.tail()
# Out:
#          Unnamed: 0           시군구     번지   본번  부번    단지명  전용면적(㎡)    계약년월  \
# 2978856      973084  충청북도 충주시 호암동  547-6  547   6   호반현대  59.7600  202004
# 2978857      973085  충청북도 충주시 호암동  547-6  547   6   호반현대  84.9600  202004
# 2978858      973086  충청북도 충주시 호암동  547-6  547   6   호반현대  84.9600  202004
# 2978859      973087  충청북도 충주시 호암동  547-6  547   6   호반현대  59.7600  202004
# 2978860      973088  충청북도 충주시 호암동    905  905   0  호암동수채  84.9254  202004
#
#          계약일 거래금액(만원)   층  건축년도        도로명
# 2978856    7    7,800   4  1994    신촌2길 29
# 2978857   10    9,500  10  1994    신촌2길 29
# 2978858   16   10,700   5  1994    신촌2길 29
# 2978859   28    7,900  13  1994    신촌2길 29
# 2978860   21   17,200  10  2007  호암중앙1로 47

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# 시군구             0
# 번지            247
# 본번              0
# 부번              0
# 단지명             0
# 전용면적(㎡)         0
# 계약년월            0
# 계약일             0
# 거래금액(만원)        0
# 층               0
# 건축년도            0
# 도로명             0
# dtype: int64

# %%
# 거래금액 int로 바꾸고, 부번은 object으로 바꾸기. 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2978861 entries, 0 to 2978860
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   시군구         object
#  2   번지          object
#  3   본번          object
#  4   부번          int64
#  5   단지명         object
#  6   전용면적(㎡)     float64
#  7   계약년월        int64
#  8   계약일         int64
#  9   거래금액(만원)    object
#  10  층           int64
#  11  건축년도        int64
#  12  도로명         object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 295.4+ MB

# %%
df["부번"].astype(object)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 2978856    6
# 2978857    6
# 2978858    6
# 2978859    6
# 2978860    0
# Name: 부번, Length: 2978861, dtype: object

# %%
def remove_comma(x):
    return x.replace(',', '')

# %%
df["거래금액(만원)"]=df["거래금액(만원)"].apply(remove_comma)

# %%
df.head()
# Out:
#    Unnamed: 0          시군구   번지   본번  부번           단지명  전용면적(㎡)    계약년월  계약일  \
# 0           0  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   13
# 1           1  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   21
# 2           2  강원도 강릉시 견소동  202  202   0          송정한신   84.945  201504   27
# 3           3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    1
# 4           4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    8
#
#   거래금액(만원)   층  건축년도           도로명
# 0     6300  15  1997   경강로2539번길 8
# 1     7700  15  1997   경강로2539번길 8
# 2    14000  10  1997   경강로2539번길 8
# 3    14500  13  2005  경강로2539번길 22
# 4    14000   7  2005  경강로2539번길 22

# %%
df["거래금액(만원)"]=df["거래금액(만원)"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2978861 entries, 0 to 2978860
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   시군구         object
#  2   번지          object
#  3   본번          object
#  4   부번          int64
#  5   단지명         object
#  6   전용면적(㎡)     float64
#  7   계약년월        int64
#  8   계약일         int64
#  9   거래금액(만원)    float64
#  10  층           int64
#  11  건축년도        int64
#  12  도로명         object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 295.4+ MB

# %% [markdown]
# # 군집
#
# 도 중에 연도별, 월별로 변화(증가,감소) 상관분석. 어떤 지역이 서로 비슷한지. 군집으로 비슷한 지역을 찾기
# ccf(시계열 상관분석): 시간차에 따른 변화

# %%
df["시군구"]
# Out:
# 0           강원도 강릉시 견소동
# 1           강원도 강릉시 견소동
# 2           강원도 강릉시 견소동
# 3           강원도 강릉시 견소동
# 4           강원도 강릉시 견소동
#                ...
# 2978856    충청북도 충주시 호암동
# 2978857    충청북도 충주시 호암동
# 2978858    충청북도 충주시 호암동
# 2978859    충청북도 충주시 호암동
# 2978860    충청북도 충주시 호암동
# Name: 시군구, Length: 2978861, dtype: object

# %%
df['시군구'].str.split(" ")
# Out:
# 0           [강원도, 강릉시, 견소동]
# 1           [강원도, 강릉시, 견소동]
# 2           [강원도, 강릉시, 견소동]
# 3           [강원도, 강릉시, 견소동]
# 4           [강원도, 강릉시, 견소동]
#                  ...
# 2978856    [충청북도, 충주시, 호암동]
# 2978857    [충청북도, 충주시, 호암동]
# 2978858    [충청북도, 충주시, 호암동]
# 2978859    [충청북도, 충주시, 호암동]
# 2978860    [충청북도, 충주시, 호암동]
# Name: 시군구, Length: 2978861, dtype: object

# %%
df['지역']=df['시군구'].str.split(" ").str[0]

# %%
df['구']=df['시군구'].str.split(" ").str[1]

# %%
df.head()
# Out:
#    Unnamed: 0          시군구   번지   본번  부번           단지명  전용면적(㎡)    계약년월  계약일  \
# 0           0  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   13
# 1           1  강원도 강릉시 견소동  202  202   0          송정한신   39.080  201504   21
# 2           2  강원도 강릉시 견소동  202  202   0          송정한신   84.945  201504   27
# 3           3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    1
# 4           4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990  201504    8
#
#    거래금액(만원)   층  건축년도           도로명   지역    구
# 0    6300.0  15  1997   경강로2539번길 8  강원도  강릉시
# 1    7700.0  15  1997   경강로2539번길 8  강원도  강릉시
# 2   14000.0  10  1997   경강로2539번길 8  강원도  강릉시
# 3   14500.0  13  2005  경강로2539번길 22  강원도  강릉시
# 4   14000.0   7  2005  경강로2539번길 22  강원도  강릉시

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2978861 entries, 0 to 2978860
# Data columns (total 15 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   시군구         object
#  2   번지          object
#  3   본번          object
#  4   부번          int64
#  5   단지명         object
#  6   전용면적(㎡)     float64
#  7   계약년월        int64
#  8   계약일         int64
#  9   거래금액(만원)    float64
#  10  층           int64
#  11  건축년도        int64
#  12  도로명         object
#  13  지역          object
#  14  구           object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 340.9+ MB

# %%
df.to_csv('C:/jupyter_project/아파트 가격 변동 분석/data.csv',encoding='cp949')

# %%
df= pd.read_csv('C:/jupyter_project/아파트 가격 변동 분석/data.csv',encoding='cp949',dtype={'CODE':np.str})

# %%
plt.figure(figsize=(20,5))
sns.barplot(data=df,x="지역",y="거래금액(만원)")

# %%
plt.figure(figsize=(40,15))
sns.barplot(data=df,x="계약년월",y="거래금액(만원)")

# %%
#서브플롯 구하기

sns.catplot(data=df,x="계약년월",y="거래금액(만원)",kind="bar",col="지역",col_wrap=4)

# %%
plt.figure(figsize=(50,20))
sns.lineplot(data=df,x="계약년월",y="거래금액(만원)",hue="지역")
plt.legend(bbox_to_anchor=(1.02,1),loc=2,borderaxespad=0.)

# %%
df['평당거래금액']=df['거래금액(만원)']/df['전용면적(㎡)']

# %%
plt.figure(figsize=(20,5))
sns.barplot(data=df,x="지역",y="평당거래금액")

# %%
plt.figure(figsize=(20,5))
sns.barplot(data=df,x="지역",y="평당거래금액",hue="층")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          시군구   번지   본번  부번           단지명  전용면적(㎡)  \
# 0           0             0  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 1           1             1  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 2           2             2  강원도 강릉시 견소동  202  202   0          송정한신   84.945
# 3           3             3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
# 4           4             4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
#
#      계약년월  계약일  거래금액(만원)   층  건축년도           도로명   지역    구      평당거래금액
# 0  201504   13    6300.0  15  1997   경강로2539번길 8  강원도  강릉시  161.207779
# 1  201504   21    7700.0  15  1997   경강로2539번길 8  강원도  강릉시  197.031730
# 2  201504   27   14000.0  10  1997   경강로2539번길 8  강원도  강릉시  164.812526
# 3  201504    1   14500.0  13  2005  경강로2539번길 22  강원도  강릉시  241.706951
# 4  201504    8   14000.0   7  2005  경강로2539번길 22  강원도  강릉시  233.372229

# %%
df['date'] = df['계약년월'].astype(str)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          시군구   번지   본번  부번           단지명  전용면적(㎡)  \
# 0           0             0  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 1           1             1  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 2           2             2  강원도 강릉시 견소동  202  202   0          송정한신   84.945
# 3           3             3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
# 4           4             4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
#
#      계약년월  계약일  거래금액(만원)   층  건축년도           도로명   지역    구      평당거래금액  \
# 0  201504   13    6300.0  15  1997   경강로2539번길 8  강원도  강릉시  161.207779
# 1  201504   21    7700.0  15  1997   경강로2539번길 8  강원도  강릉시  197.031730
# 2  201504   27   14000.0  10  1997   경강로2539번길 8  강원도  강릉시  164.812526
# 3  201504    1   14500.0  13  2005  경강로2539번길 22  강원도  강릉시  241.706951
# 4  201504    8   14000.0   7  2005  경강로2539번길 22  강원도  강릉시  233.372229
#
#      date day
# 0  201504  13
# 1  201504  21
# 2  201504  27
# ...

# %%
df['datetime'] = df['date'] + '10'

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          시군구   번지   본번  부번           단지명  전용면적(㎡)  \
# 0           0             0  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 1           1             1  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 2           2             2  강원도 강릉시 견소동  202  202   0          송정한신   84.945
# 3           3             3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
# 4           4             4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
#
#      계약년월  계약일  거래금액(만원)   층  건축년도           도로명   지역    구      평당거래금액  \
# 0  201504   13    6300.0  15  1997   경강로2539번길 8  강원도  강릉시  161.207779
# 1  201504   21    7700.0  15  1997   경강로2539번길 8  강원도  강릉시  197.031730
# 2  201504   27   14000.0  10  1997   경강로2539번길 8  강원도  강릉시  164.812526
# 3  201504    1   14500.0  13  2005  경강로2539번길 22  강원도  강릉시  241.706951
# 4  201504    8   14000.0   7  2005  경강로2539번길 22  강원도  강릉시  233.372229
#
#      date day  datetime
# 0  201504  13  20150410
# ...

# %%
df['datetime']=pd.to_datetime(df['datetime'])

# %%
df['월']=df['datetime'].dt.strftime('%m')

# %%
df['연도']=df['datetime'].dt.strftime('%Y')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          시군구   번지   본번  부번           단지명  전용면적(㎡)  \
# 0           0             0  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 1           1             1  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 2           2             2  강원도 강릉시 견소동  202  202   0          송정한신   84.945
# 3           3             3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
# 4           4             4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
#
#      계약년월  계약일  ...  건축년도           도로명   지역    구      평당거래금액    date  day  \
# 0  201504   13  ...  1997   경강로2539번길 8  강원도  강릉시  161.207779  201504   13
# 1  201504   21  ...  1997   경강로2539번길 8  강원도  강릉시  197.031730  201504   21
# 2  201504   27  ...  1997   경강로2539번길 8  강원도  강릉시  164.812526  201504   27
# 3  201504    1  ...  2005  경강로2539번길 22  강원도  강릉시  241.706951  201504    1
# 4  201504    8  ...  2005  경강로2539번길 22  강원도  강릉시  233.372229  201504    8
#
#     datetime   월    연도
# ...

# %%
df=df.drop(["date","day","datetime"],axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          시군구   번지   본번  부번           단지명  전용면적(㎡)  \
# 0           0             0  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 1           1             1  강원도 강릉시 견소동  202  202   0          송정한신   39.080
# 2           2             2  강원도 강릉시 견소동  202  202   0          송정한신   84.945
# 3           3             3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
# 4           4             4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   59.990
#
#      계약년월  계약일  거래금액(만원)   층  건축년도           도로명   지역    구      평당거래금액   월  \
# 0  201504   13    6300.0  15  1997   경강로2539번길 8  강원도  강릉시  161.207779  04
# 1  201504   21    7700.0  15  1997   경강로2539번길 8  강원도  강릉시  197.031730  04
# 2  201504   27   14000.0  10  1997   경강로2539번길 8  강원도  강릉시  164.812526  04
# 3  201504    1   14500.0  13  2005  경강로2539번길 22  강원도  강릉시  241.706951  04
# 4  201504    8   14000.0   7  2005  경강로2539번길 22  강원도  강릉시  233.372229  04
#
#      연도
# 0  2015
# 1  2015
# 2  2015
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            부번       전용면적(㎡)  \
# count  2.978861e+06  2.978861e+06    2.978861e+06  2.978861e+06  2.978861e+06
# mean   1.489430e+06  1.489430e+06    4.966994e+05  4.912108e+00  7.584214e+01
# std    8.599232e+05  8.599232e+05    2.870302e+05  3.929804e+01  2.678130e+01
# min    0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00  9.260000e+00
# 25%    7.447150e+05  7.447150e+05    2.482380e+05  0.000000e+00  5.967940e+01
# 50%    1.489430e+06  1.489430e+06    4.964760e+05  0.000000e+00  7.819000e+01
# 75%    2.234145e+06  2.234145e+06    7.447150e+05  1.000000e+00  8.496000e+01
# max    2.978860e+06  2.978860e+06    1.022081e+06  2.837000e+03  4.243200e+02
#
#                계약년월           계약일      거래금액(만원)             층          건축년도  \
# count  2.978861e+06  2.978861e+06  2.978861e+06  2.978861e+06  2.978861e+06
# mean   2.017271e+05  1.574559e+01  3.072180e+04  9.025289e+00  2.000764e+03
# ...

# %%
df.to_csv('C:/jupyter_project/아파트 가격 변동 분석/data2.csv',encoding='cp949')

# %%
df= pd.read_csv('C:/jupyter_project/아파트 가격 변동 분석/data2.csv',encoding='cp949',dtype={'CODE':np.str})

# %%
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
df.corr()['층'].sort_values()
# Out:
# 부번                 -0.020097
# 계약일                 0.000662
# 월                   0.010586
# Unnamed: 0.1.1.1    0.014550
# 연도                  0.045393
# 계약년월                0.045812
# Unnamed: 0          0.047470
# Unnamed: 0.1        0.047470
# 평당거래금액              0.139480
# 전용면적(㎡)             0.167152
# 거래금액(만원)            0.185953
# 건축년도                0.272546
# 층                   1.000000
# Name: 층, dtype: float64

# %%
sns.distplot(df['평당거래금액'])

# %%
df['평당거래금액']=np.log1p(df['평당거래금액'])
sns.distplot(df['평당거래금액'])

# %%
df['평당거래금액'].describe()
# Out:
# count    2.978861e+06
# mean     5.805508e+00
# std      5.842081e-01
# min      5.442569e-01
# 25%      5.436348e+00
# 50%      5.788427e+00
# 75%      6.157785e+00
# max      8.849458e+00
# Name: 평당거래금액, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1.1          시군구   번지   본번  부번  \
# 0           0             0                 0  강원도 강릉시 견소동  202  202   0
# 1           1             1                 1  강원도 강릉시 견소동  202  202   0
# 2           2             2                 2  강원도 강릉시 견소동  202  202   0
# 3           3             3                 3  강원도 강릉시 견소동  289  289   0
# 4           4             4                 4  강원도 강릉시 견소동  289  289   0
#
#             단지명  전용면적(㎡)    계약년월  계약일  거래금액(만원)   층  건축년도           도로명   지역  \
# 0          송정한신   39.080  201504   13    6300.0  15  1997   경강로2539번길 8  강원도
# 1          송정한신   39.080  201504   21    7700.0  15  1997   경강로2539번길 8  강원도
# 2          송정한신   84.945  201504   27   14000.0  10  1997   경강로2539번길 8  강원도
# 3  송정해변신도브래뉴아파트   59.990  201504    1   14500.0  13  2005  경강로2539번길 22  강원도
# 4  송정해변신도브래뉴아파트   59.990  201504    8   14000.0   7  2005  경강로2539번길 22  강원도
#
#      구      평당거래금액  월    연도
# 0  강릉시  161.207779  4  2015
# ...
